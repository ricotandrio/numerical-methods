# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set()  

size = 200
x = np.linspace(-np.pi, np.pi, size)
y = np.zeros(len(x))
around = 0 
order_asked =

plt.figure(figsize=(6, 5))
counter = 0
for n in range(order_asked + 1):
    if n % 2 == 0:
        y += (np.sin(around) / np.math.factorial(n)) * ((-1) ** counter) * ((x) ** n)
    else: 
        y += (np.cos(around) / np.math.factorial(n)) * ((-1) ** counter) * ((x) ** n)
        counter += 1 

plt.plot(x, y, label="Taylor Series for Order {}".format(order_asked))
plt.plot(x, np.sin(x), "k", label="Analytical Method")
plt.title("Taylor Series Approximations")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
